# %%
import pandas as pd
import numpy as np

# %%
p = pd.read_csv("OilSpills-Production with deltas.csv")
#p = data.toPandas()
p
# Out:
#                                        Spill / Vessel  \
# 0                           Norilsk diesel fuel spill
# 1                        Keystone Pipeline 2019 spill
# 2   Guarello Island iron ore export terminal diese...
# 3                  SeaRose FPSO production ship spill
# 4                        Keystone Pipeline 2017 spill
# 5                     East River insulating oil spill
# 6             BP Clair production platform, North Sea
# 7                     North Battleford pipeline spill
# 8                ConocoPhillips Canada pipeline spill
# 9                   2016 Union Pacific oil train fire
# 10          Denbury Resources Bowman County Oil SPill
# 11  Shell Gulf of Mexico oil spill, Brutus offshor...
# 12                       Keystone Pipeline 2016 spill
# 13                                  Refugio oil spill
# 14                       Black Sea oil pipeline spill
# 15                                Mid-Valley Pipeline
# ...

# %%
labels = p['Trading Name']
labels
# Out:
# 0         NILSY
# 1           TRP
# 2        CAP.SN
# 3        HSE.TO
# 4           TRP
# 5            ED
# 6            BP
# 7        HSE.TO
# 8           COP
# 9           UNP
# 10          DNR
# 11        RDS-A
# 12          TRP
# 13          PAA
# 14     TRNFP.ME
# 15          SUN
# 16           BP
# 17          KEX
# 18     PTTGC.BK
# 19          EEP
# 20          XOM
# 21          DKL
# 22          XOM
# 23          PAA
# 24        RDS-A
# 25          CVX
# 26         CMRE
# 27        RDS-A
# 28          XOM
# 29          COP
# 30          PAA
# 31      ONGC.NS
# 32          TRP
# 33          XOM
# 34           BP
# 35    000027.SZ
# 36        RDS-A
# 37        STOHF
# 38          XOM
# 39        CPYYY
# 40           BP
# 41        RDS-A
# 42          CVX
# 43          MUR
# 44          CVX
# 45        RDS-A
# 46          CVX
# 47          BHP
# 48           BP
# 49           BP
# 50          XOM
# 51          XOM
# 52          ASH
# 53          CVX
# ...

# %%
features = ["Dates", "Min Tonnes", "Max Tonnes", "Day Prior", "Day After", "1 Day Change", "1 Day % Change", "1 Day Result", "1 Month", "1 Month Change", "1 Month % Change", "1 Month Result", "6 Months", "6 Months Change", "6 Months % Change", "6 Months Result", "1 Year", "1 Year Change", "1 Year % Change", "1 Year Result", "2 Years", "2 Years Change", "2 Years % Change", "2 Years Result"]

# %%
features
# Out:
# ['Dates',
#  'Min Tonnes',
#  'Max Tonnes',
#  'Day Prior',
#  'Day After',
#  '1 Day Change',
#  '1 Day % Change',
#  '1 Day Result',
#  '1 Month',
#  '1 Month Change',
#  '1 Month % Change',
#  '1 Month Result',
#  '6 Months',
#  '6 Months Change',
#  '6 Months % Change',
#  '6 Months Result',
#  '1 Year',
#  '1 Year Change',
#  '1 Year % Change',
#  '1 Year Result',
#  '2 Years',
#  '2 Years Change',
#  '2 Years % Change',
#  '2 Years Result']

# %%
X = p.loc[:,features]
X
# Out:
#                       Dates Min Tonnes Max Tonnes     Day Prior     Day After  \
# 0   2020-05-29 - 2020-05-29     17,500     17,500     31.600000     32.150002
# 1   2019-10-29 - 2019-10-29      1,240      1,240     48.236511     47.743237
# 2   2019-07-27 - 2019-07-27       35.4       35.4   7189.360352   7125.345703
# 3   2018-11-16 - 2018-11-16        219        219     16.168104     15.280444
# 4   2017-11-16 - 2017-11-16      1,322      1,322     40.637478     40.917850
# 5   2017-05-07 - 2017-05-07         97        101     70.377281     69.495476
# 6   2016-10-02 - 2016-10-02        105        105     27.173248     27.575129
# 7   2016-07-21 - 2016-07-21        170        210     13.789442     13.959132
# 8   2016-06-09 - 2016-06-09        323        323     42.401638     39.178440
# 9   2016-06-03 - 2016-06-03        152        152     77.034256     79.073700
# 10  2016-05-18 - 2016-05-18         44         44      4.230000      4.030000
# ...

# %%
#setup plot
import matplotlib.pyplot as plt
print(plt.rcParams.get('figure.figsize'))
# Out:
# [6.0, 4.0]

# %%
#setup figure size
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20
plt.rcParams["figure.figsize"] = fig_size

# %%
Y = p["1 Day Result"]
Y
# Out:
# 0     L
# 1     L
# 2     L
# 3     L
# 4     L
# 5     L
# 6     L
# 7     L
# 8     L
# 9     L
# 10    L
# 11    L
# 12    L
# 13    L
# 14    L
# 15    L
# 16    L
# 17    L
# 18    L
# 19    L
# 20    L
# 21    L
# 22    L
# 23    L
# 24    L
# 25    L
# 26    L
# 27    L
# 28    L
# 29    L
# 30    L
# 31    L
# 32    L
# 33    L
# 34    L
# 35    L
# 36    L
# 37    L
# 38    L
# 39    L
# 40    L
# 41    L
# 42    W
# 43    W
# 44    W
# 45    W
# 46    L
# 47    L
# 48    L
# 49    L
# 50    L
# 51    L
# 52    L
# 53    L
# Name: 1 Day Result, dtype: object

# %%
from platform import python_version
print(python_version())
import sklearn
# Out:
# 3.8.3

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %%
print('The scikit-learn version is {}.'.format(sklearn.__version__))
from sklearn import tree
from sklearn.model_selection import cross_val_score
#set how many folds/combinations you want
k=5
clf = tree.DecisionTreeClassifier(random_state=0)
#X is all features and Y is all labels, cv performs the split
scores = cross_val_score(clf, X, Y, cv=k)
#clf = clf.fit(X, Y)
scores
# Out:
# The scikit-learn version is 0.23.1.
# C:\Users\jmcan\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\jmcan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\jmcan\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jmcan\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 890, in fit
#     super().fit(
#   File "C:\Users\jmcan\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 156, in fit
#     X, y = self._validate_data(X, y,
# ...
